# %%
print("Introduction to Pandas")
# Out:
# Introduction to Pandas

# %% [markdown]
# key data structure in pandas
# series 1 D
# dataframe 2 D

# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,4,5], index=['a','b','c','d','e'])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
df = pd.DataFrame({"names":["Asim","Arslan","Husnain"], "marks" :[10,5,3]})

# %%
df
# Out:
#      names  marks
# 0     Asim     10
# 1   Arslan      5
# 2  Husnain      3

# %%
df = pd.read_csv('results.csv')

# %%
df
# Out:
#     epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0       1   1377.12         0.92683         3.01268         1.29447
# 1       2   2691.81         0.98687         2.04577         1.31826
# 2       3   4044.62         1.01341         1.89998         1.33223
# 3       4   5340.32         0.99138         1.60765         1.29215
# 4       5   6647.56         0.98461         1.47336         1.29029
# 5       6   7937.42         0.95702         1.32046         1.27668
# 6       7  10352.30         0.91014         1.21904         1.25606
# 7       8  12321.20         0.90293         1.13792         1.24811
# 8       9  13668.20         0.88159         1.05668         1.23742
# 9      10  14980.90         0.83851         1.03829         1.19983
# 10     11  16214.90         0.76671         0.99777         1.19351
# 11     12  17545.30         0.74243         0.91985         1.16281
# 12     13  18797.30         0.72617         0.86054         1.15764
# ...

# %%
df.head()
# Out:
#    epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0      1  1377.12         0.92683         3.01268         1.29447
# 1      2  2691.81         0.98687         2.04577         1.31826
# 2      3  4044.62         1.01341         1.89998         1.33223
# 3      4  5340.32         0.99138         1.60765         1.29215
# 4      5  6647.56         0.98461         1.47336         1.29029
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0               0.82979            0.20143           0.34406
# 1               0.79823            0.43413           0.42313
# 2               0.78842            0.46491           0.48906
# 3               0.62935            0.43884           0.46340
# 4               0.83680            0.42407           0.50473
#
#    metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 0              0.23228       0.97668       3.84033       1.36804  0.000366
# ...

# %%
df.tail()
# Out:
#     epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 15     16  22537.0         0.65317         0.72936         1.08782
# 16     17  23764.5         0.64374         0.69958         1.09747
# 17     18  25577.4         0.61280         0.66784         1.07875
# 18     19  26816.3         0.59747         0.64801         1.06062
# 19     20  28089.6         0.57815         0.61103         1.05809
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 15               0.76234            0.64558           0.63322
# 16               0.82843            0.60095           0.63504
# 17               0.82308            0.62174           0.63242
# 18               0.83849            0.62336           0.65009
# 19               0.84200            0.60896           0.63785
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 15              0.48971       0.74846       0.84562       1.20200  0.000286
# ...

# %%
df.describe()
# Out:
#           epoch        time  train/box_loss  train/cls_loss  train/dfl_loss  \
# count  20.00000     20.0000       20.000000       20.000000       20.000000
# mean   10.50000  15003.8975        0.804244        1.176958        1.194029
# std     5.91608   8413.3107        0.150494        0.596235        0.092583
# min     1.00000   1377.1200        0.578150        0.611030        1.058090
# 25%     5.75000   7614.9550        0.665057        0.763373        1.107220
# 50%    10.50000  15597.9000        0.802610        1.018030        1.196670
# 75%    15.25000  21613.9750        0.934378        1.358685        1.280083
# max    20.00000  28089.6000        1.013410        3.012680        1.332230
#
#        metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# count             20.000000          20.000000         20.000000
# mean               0.793295           0.534375          0.562012
# std                0.050795           0.103737          0.081388
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   epoch                 20 non-null     int64
#  1   time                  20 non-null     float64
#  2   train/box_loss        20 non-null     float64
#  3   train/cls_loss        20 non-null     float64
#  4   train/dfl_loss        20 non-null     float64
#  5   metrics/precision(B)  20 non-null     float64
#  6   metrics/recall(B)     20 non-null     float64
#  7   metrics/mAP50(B)      20 non-null     float64
#  8   metrics/mAP50-95(B)   20 non-null     float64
#  9   val/box_loss          20 non-null     float64
#  10  val/cls_loss          20 non-null     float64
#  11  val/dfl_loss          20 non-null     float64
#  12  lr/pg0                20 non-null     float64
#  13  lr/pg1                20 non-null     float64
# ...

# %%
df[["epoch","time"]]
# Out:
#     epoch      time
# 0       1   1377.12
# 1       2   2691.81
# 2       3   4044.62
# 3       4   5340.32
# 4       5   6647.56
# 5       6   7937.42
# 6       7  10352.30
# 7       8  12321.20
# 8       9  13668.20
# 9      10  14980.90
# 10     11  16214.90
# 11     12  17545.30
# 12     13  18797.30
# 13     14  20067.90
# 14     15  21306.30
# 15     16  22537.00
# 16     17  23764.50
# 17     18  25577.40
# 18     19  26816.30
# 19     20  28089.60

# %%
df.iloc[0]
# Out:
# epoch                      1.000000
# time                    1377.120000
# train/box_loss             0.926830
# train/cls_loss             3.012680
# train/dfl_loss             1.294470
# metrics/precision(B)       0.829790
# metrics/recall(B)          0.201430
# metrics/mAP50(B)           0.344060
# metrics/mAP50-95(B)        0.232280
# val/box_loss               0.976680
# val/cls_loss               3.840330
# val/dfl_loss               1.368040
# lr/pg0                     0.000366
# lr/pg1                     0.000366
# lr/pg2                     0.000366
# Name: 0, dtype: float64

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %%
df.dropna()
# Out:
#     epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0       1   1377.12         0.92683         3.01268         1.29447
# 1       2   2691.81         0.98687         2.04577         1.31826
# 2       3   4044.62         1.01341         1.89998         1.33223
# 3       4   5340.32         0.99138         1.60765         1.29215
# 4       5   6647.56         0.98461         1.47336         1.29029
# 5       6   7937.42         0.95702         1.32046         1.27668
# 6       7  10352.30         0.91014         1.21904         1.25606
# 7       8  12321.20         0.90293         1.13792         1.24811
# 8       9  13668.20         0.88159         1.05668         1.23742
# 9      10  14980.90         0.83851         1.03829         1.19983
# 10     11  16214.90         0.76671         0.99777         1.19351
# 11     12  17545.30         0.74243         0.91985         1.16281
# 12     13  18797.30         0.72617         0.86054         1.15764
# ...

# %%
df.fillna(0 )
# Out:
#     epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0       1   1377.12         0.92683         3.01268         1.29447
# 1       2   2691.81         0.98687         2.04577         1.31826
# 2       3   4044.62         1.01341         1.89998         1.33223
# 3       4   5340.32         0.99138         1.60765         1.29215
# 4       5   6647.56         0.98461         1.47336         1.29029
# 5       6   7937.42         0.95702         1.32046         1.27668
# 6       7  10352.30         0.91014         1.21904         1.25606
# 7       8  12321.20         0.90293         1.13792         1.24811
# 8       9  13668.20         0.88159         1.05668         1.23742
# 9      10  14980.90         0.83851         1.03829         1.19983
# 10     11  16214.90         0.76671         0.99777         1.19351
# 11     12  17545.30         0.74243         0.91985         1.16281
# 12     13  18797.30         0.72617         0.86054         1.15764
# ...

# %%
df.rename(columns={"time": "Time"},inplace=False)
# Out:
#     epoch      Time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0       1   1377.12         0.92683         3.01268         1.29447
# 1       2   2691.81         0.98687         2.04577         1.31826
# 2       3   4044.62         1.01341         1.89998         1.33223
# 3       4   5340.32         0.99138         1.60765         1.29215
# 4       5   6647.56         0.98461         1.47336         1.29029
# 5       6   7937.42         0.95702         1.32046         1.27668
# 6       7  10352.30         0.91014         1.21904         1.25606
# 7       8  12321.20         0.90293         1.13792         1.24811
# 8       9  13668.20         0.88159         1.05668         1.23742
# 9      10  14980.90         0.83851         1.03829         1.19983
# 10     11  16214.90         0.76671         0.99777         1.19351
# 11     12  17545.30         0.74243         0.91985         1.16281
# 12     13  18797.30         0.72617         0.86054         1.15764
# ...

# %%
df
# Out:
#     epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0       1   1377.12         0.92683         3.01268         1.29447
# 1       2   2691.81         0.98687         2.04577         1.31826
# 2       3   4044.62         1.01341         1.89998         1.33223
# 3       4   5340.32         0.99138         1.60765         1.29215
# 4       5   6647.56         0.98461         1.47336         1.29029
# 5       6   7937.42         0.95702         1.32046         1.27668
# 6       7  10352.30         0.91014         1.21904         1.25606
# 7       8  12321.20         0.90293         1.13792         1.24811
# 8       9  13668.20         0.88159         1.05668         1.23742
# 9      10  14980.90         0.83851         1.03829         1.19983
# 10     11  16214.90         0.76671         0.99777         1.19351
# 11     12  17545.30         0.74243         0.91985         1.16281
# 12     13  18797.30         0.72617         0.86054         1.15764
# ...

# %%
df.describe()
# Out:
#           epoch        time  train/box_loss  train/cls_loss  train/dfl_loss  \
# count  20.00000     20.0000       20.000000       20.000000       20.000000
# mean   10.50000  15003.8975        0.804244        1.176958        1.194029
# std     5.91608   8413.3107        0.150494        0.596235        0.092583
# min     1.00000   1377.1200        0.578150        0.611030        1.058090
# 25%     5.75000   7614.9550        0.665057        0.763373        1.107220
# 50%    10.50000  15597.9000        0.802610        1.018030        1.196670
# 75%    15.25000  21613.9750        0.934378        1.358685        1.280083
# max    20.00000  28089.6000        1.013410        3.012680        1.332230
#
#        metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# count             20.000000          20.000000         20.000000
# mean               0.793295           0.534375          0.562012
# std                0.050795           0.103737          0.081388
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   epoch                 20 non-null     int64
#  1   time                  20 non-null     float64
#  2   train/box_loss        20 non-null     float64
#  3   train/cls_loss        20 non-null     float64
#  4   train/dfl_loss        20 non-null     float64
#  5   metrics/precision(B)  20 non-null     float64
#  6   metrics/recall(B)     20 non-null     float64
#  7   metrics/mAP50(B)      20 non-null     float64
#  8   metrics/mAP50-95(B)   20 non-null     float64
#  9   val/box_loss          20 non-null     float64
#  10  val/cls_loss          20 non-null     float64
#  11  val/dfl_loss          20 non-null     float64
#  12  lr/pg0                20 non-null     float64
#  13  lr/pg1                20 non-null     float64
# ...

# %%
df['epoch'] = df['epoch'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   epoch                 20 non-null     object
#  1   time                  20 non-null     float64
#  2   train/box_loss        20 non-null     float64
#  3   train/cls_loss        20 non-null     float64
#  4   train/dfl_loss        20 non-null     float64
#  5   metrics/precision(B)  20 non-null     float64
#  6   metrics/recall(B)     20 non-null     float64
#  7   metrics/mAP50(B)      20 non-null     float64
#  8   metrics/mAP50-95(B)   20 non-null     float64
#  9   val/box_loss          20 non-null     float64
#  10  val/cls_loss          20 non-null     float64
#  11  val/dfl_loss          20 non-null     float64
#  12  lr/pg0                20 non-null     float64
#  13  lr/pg1                20 non-null     float64
# ...

# %%
df
# Out:
#     epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0       1   1377.12         0.92683         3.01268         1.29447
# 1       2   2691.81         0.98687         2.04577         1.31826
# 2       3   4044.62         1.01341         1.89998         1.33223
# 3       4   5340.32         0.99138         1.60765         1.29215
# 4       5   6647.56         0.98461         1.47336         1.29029
# 5       6   7937.42         0.95702         1.32046         1.27668
# 6       7  10352.30         0.91014         1.21904         1.25606
# 7       8  12321.20         0.90293         1.13792         1.24811
# 8       9  13668.20         0.88159         1.05668         1.23742
# 9      10  14980.90         0.83851         1.03829         1.19983
# 10     11  16214.90         0.76671         0.99777         1.19351
# 11     12  17545.30         0.74243         0.91985         1.16281
# 12     13  18797.30         0.72617         0.86054         1.15764
# ...

# %%
len(df)
# Out:
# 20

# %%
df["zeros"] = [0 for i in range(len(df))]

# %%
df
# Out:
#    epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0      1   1377.12         0.92683         3.01268         1.29447
# 1      2   2691.81         0.98687         2.04577         1.31826
# 2      3   4044.62         1.01341         1.89998         1.33223
# 3      4   5340.32         0.99138         1.60765         1.29215
# 4      5   6647.56         0.98461         1.47336         1.29029
# 5      6   7937.42         0.95702         1.32046         1.27668
# 6      7  10352.30         0.91014         1.21904         1.25606
# 7      8  12321.20         0.90293         1.13792         1.24811
# 8      9  13668.20         0.88159         1.05668         1.23742
# 9     10  14980.90         0.83851         1.03829         1.19983
# 10    11  16214.90         0.76671         0.99777         1.19351
# 11    12  17545.30         0.74243         0.91985         1.16281
# 12    13  18797.30         0.72617         0.86054         1.15764
# ...

# %%
def fx(a):
    return a*a
df["zeros * 2"] = df["time"].apply(fx)

# %%
df
# Out:
#    epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0      1   1377.12         0.92683         3.01268         1.29447
# 1      2   2691.81         0.98687         2.04577         1.31826
# 2      3   4044.62         1.01341         1.89998         1.33223
# 3      4   5340.32         0.99138         1.60765         1.29215
# 4      5   6647.56         0.98461         1.47336         1.29029
# 5      6   7937.42         0.95702         1.32046         1.27668
# 6      7  10352.30         0.91014         1.21904         1.25606
# 7      8  12321.20         0.90293         1.13792         1.24811
# 8      9  13668.20         0.88159         1.05668         1.23742
# 9     10  14980.90         0.83851         1.03829         1.19983
# 10    11  16214.90         0.76671         0.99777         1.19351
# 11    12  17545.30         0.74243         0.91985         1.16281
# 12    13  18797.30         0.72617         0.86054         1.15764
# ...

# %%
df.to_csv("export.csv", index=False)
